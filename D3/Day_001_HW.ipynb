# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)
# * 平均絕對誤差 - Mean Absolute Error (MAE)
# * 平均平方誤差(均方差) - Mean Squared Error (MSE)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
# numpy 常用於數值/陣列運算, pandas 擅長資料格式的調整, matplotlib 擅長繪圖
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y,yp):

    mae=MAE= sum(y-yp)**2/ len(y)
    return mae

# %%
#  np.linspace(0, 100, 101)是指 0~100 劃分成 101 個刻度(含頭尾), 所也就是 0, 1, 2,...,100 這 101 個數
# 這時候, x_lin 因為要記錄不只一個數, 因為 np.linspace() 傳回的是一個 Array, 所以 x_lin 就變成 Array 了
# np.random.randn() 就是 numpy.random.randn(), 會隨機 傳回 標準常態分布的取樣值
# np.random.randn(101) 表示取樣了101次, 型態是 Array, 所以其他 + 與 * 的部分都是 Array 的加與乘, 一行就計算了101筆資料
# 所以最後的結果 y, 也是一個長度 101 的 Array
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 254.053
# The Mean absolute error is 12.478

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 這組資料想解決的問題如何評估

# %% [markdown]
# Database：https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/overview
#
# 1. 根據房子的各式特徵預測每棟房子的銷售價格，讓買賣雙方可以更了解房子的賣點以及價格高低的主要原因，對於買方能提供透明化的屋況狀態，最大化滿足買方的需求；對於賣方來說可以確保定價合理達到最大的銷售利潤。
# 2. 這些資料來自Kaggle平台上的一個房價預測競賽，由MIT提供此資料集。
# 3. 資料集包含.csv格式及.txt格式的檔案，train.csv中包含String（96）、Integer（61）、Id（3）等，並且有txt檔案詳細解釋數據轉換的過程，可以通過data.info()來了解數據的詳細信息，並在之後會使用特徵工程找出模型的關鍵因數。
# 4.
#    1. 解決問題：針對市面上的房子，可以套用該模型快速得出房子的販售價格，減少人工作業的時間。
#    2. 使用test.csv檢視先前建立的模型準確度。

# %% [markdown]
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

# %% [markdown]
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

# %% [markdown]
# 1.  提升業績跟提升載客數量有正相關
#     減少空車率跟提升載客數量有正相關
#     司機可以在最後一單時接到回家同方向的客人以增加司機的載客意願和公司業績。
# 2.  從線上的台灣大車隊公開的資料中，收集車隊中每輛車的載客數及路線資料。
# 3.  型態會有路線、載客數、金額、距離、上車地點、下車地點、空車狀態、司機下班時間。
# 4.  透過分析不同特徵與提升業績的關聯性，依照模型關聯性最高的特徵，搭配乘客出現較高機率的的上下車地點及路線，指定計程車於特定地點等待，進而驗證公司的業績是否提升。
